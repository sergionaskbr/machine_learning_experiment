# %% [markdown]
# # LOGISTIC REGRESSION CLASSIFIER

# %% [markdown]
# ## 0. Imports

# %%
import numpy as np
import pandas as pd
from sklearn import metrics as mt
from sklearn import linear_model as lm
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1. Load Datasets

# %%
# Train Datasets
dataset_path = '../../datasets/classification/X_training.csv'
x_train = pd.read_csv(dataset_path)
dataset_path2 = '../../datasets/classification/y_training.csv'
y_train = pd.read_csv(dataset_path2)

# Test Datasets
dataset_path3 = '../../datasets/classification/X_test.csv'
x_test = pd.read_csv(dataset_path3)
dataset_path4 = '../../datasets/classification/y_test.csv'
y_test = pd.read_csv(dataset_path4)

# Validation Datasets
dataset_path5 = '../../datasets/classification/X_validation.csv'
x_val = pd.read_csv(dataset_path5)
dataset_path6 = '../../datasets/classification/y_validation.csv'
y_val = pd.read_csv(dataset_path6)

# %%
y_train = y_train.values.ravel()
y_val = y_val.values.ravel()
y_test = y_test.values.ravel()

# %% [markdown]
# ## 2. Logistic Regression

# %% [markdown]
# ### 2.1 Model Definition and Training

# %%
logistic_regression = lm.LogisticRegression()
logistic_regression.fit(x_train, y_train)
# Out:
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### 2.2 Model Predict and Performance

# %%
# Predict Train
y_pred_train = logistic_regression.predict(x_train)

# Performance Metrics
accuracy_train = mt.accuracy_score(y_train, y_pred_train)
precision_train = mt.precision_score(y_train, y_pred_train)
recall_train = mt.recall_score(y_train, y_pred_train)
f1_score_train = mt.f1_score(y_train, y_pred_train)

print(f"Train Accuracy: {accuracy_train}")
print(f"Train Precision: {precision_train}")
print(f"Train Recall: {recall_train}")
print(f"Train F1 Score: {f1_score_train}")
# Out:
# Train Accuracy: 0.8725918775425774
# Train Precision: 0.8609258596571131
# Train Recall: 0.8420516736667939
# Train F1 Score: 0.8513841748837808

# %% [markdown]
# ### 2.3 Fine-tuning

# %%
# Find Best C Hyperparameter for Validation Data
c = np.arange(0.1, 2.1, 0.1)
accuracy_list = []

for i in c:
    logistic_regression = lm.LogisticRegression(C=i)
    logistic_regression.fit(x_train, y_train)
    y_pred_val = logistic_regression.predict(x_val)

    accuracy = mt.accuracy_score(y_val, y_pred_val)
    accuracy_list.append(accuracy)

plt.plot(c, accuracy_list, '-o')
plt.xlabel('C value')
plt.ylabel('Accuracy')
plt.show();
# Out:
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
best_c = accuracy_list.index(max(accuracy_list))
c[best_c]
# Out:
# 1.0

# %%
# Find Best solver Hyperparameter for Validation Data
solver = ["lbfgs", "liblinear", "newton-cg", "newton-cholesky", "sag", "saga"]
accuracy_list = []

for i in solver:
    logistic_regression = lm.LogisticRegression(C=1, solver=i)
    logistic_regression.fit(x_train, y_train)
    y_pred_val = logistic_regression.predict(x_val)

    accuracy = mt.accuracy_score(y_val, y_pred_val)
    accuracy_list.append(accuracy)

plt.plot(solver, accuracy_list, '-o')
plt.xlabel('Solver')
plt.ylabel('Accuracy')
plt.show();
# Out:
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
best_solver = accuracy_list.index(max(accuracy_list))
solver[best_solver]
# Out:
# 'newton-cg'

# %%
# Find Best max_iter Hyperparameter for Validation Data
max_iter = np.arange(100, 5000, 100)
accuracy_list = []

for i in max_iter:
    logistic_regression = lm.LogisticRegression(C=1, solver='newton-cg', max_iter=i)
    logistic_regression.fit(x_train, y_train)
    y_pred_val = logistic_regression.predict(x_val)

    accuracy = mt.accuracy_score(y_val, y_pred_val)
    accuracy_list.append(accuracy)

plt.plot(max_iter, accuracy_list, '-o')
plt.xlabel('max_iter value')
plt.ylabel('Accuracy')
plt.show();
# Out:
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(

# %%
best_max_iter = accuracy_list.index(max(accuracy_list))
max_iter[best_solver]
# Out:
# 300

# %%
# Predict Validation with Best Hyperparameters Found
logistic_regression = lm.LogisticRegression(C=1, solver='newton-cg', max_iter=300)
logistic_regression.fit(x_train, y_train)
y_pred_val = logistic_regression.predict(x_val)

# Performance Metrics
accuracy_val = mt.accuracy_score(y_val, y_pred_val)
precision_val = mt.precision_score(y_val, y_pred_val)
recall_val = mt.recall_score(y_val, y_pred_val)
f1_score_val = mt.f1_score(y_val, y_pred_val)

print(f"Validation Accuracy: {accuracy_val}")
print(f"Validation Precision: {precision_val}")
print(f"Validation Recall: {recall_val}")
print(f"Validation F1 Score: {f1_score_val}")
# Out:
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# Validation Accuracy: 0.8745455130473954
# Validation Precision: 0.8695551436515292
# Validation Recall: 0.835919518895241
# Validation F1 Score: 0.8524056478782602

# %%
# Predict Test with Best Hyperparameters Found
logistic_regression = lm.LogisticRegression(C=1, solver='newton-cg', max_iter=300)
logistic_regression.fit(x_train, y_train)
y_pred_test = logistic_regression.predict(x_test)

# Performance Metrics
accuracy_test = mt.accuracy_score(y_test, y_pred_test)
precision_test = mt.precision_score(y_test, y_pred_test)
recall_test = mt.recall_score(y_test, y_pred_test)
f1_score_test = mt.f1_score(y_test, y_pred_test)

print(f"Test Accuracy: {accuracy_test}")
print(f"Test Precision: {precision_test}")
print(f"Test Recall: {recall_test}")
print(f"Test F1 Score: {f1_score_test}")
# Out:
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/sergi/.pyenv/versions/3.12.2/envs/fundamentos_de_ml/lib/python3.12/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# Test Accuracy: 0.8712393310933457
# Test Precision: 0.8674842134163082
# Test Recall: 0.8340519137703476
# Test F1 Score: 0.8504396195944733
