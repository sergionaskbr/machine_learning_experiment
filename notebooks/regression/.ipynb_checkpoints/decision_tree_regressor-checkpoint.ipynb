# %% [markdown]
# # DECISION TREE REGRESSOR

# %% [markdown]
# ## 0. Imports

# %%
import numpy as np
import pandas as pd
from sklearn import metrics as mt
from sklearn import model_selection as ms
from sklearn import tree as tr
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1. Load Datasets

# %%
# Train Datasets
dataset_path = '../../datasets/regression/X_training.csv'
x_train = pd.read_csv(dataset_path)
dataset_path2 = '../../datasets/regression/y_training.csv'
y_train = pd.read_csv(dataset_path2)

# Test Datasets
dataset_path3 = '../../datasets/regression/X_test.csv'
x_test = pd.read_csv(dataset_path3)
dataset_path4 = '../../datasets/regression/y_test.csv'
y_test = pd.read_csv(dataset_path4)

# Validation Datasets
dataset_path5 = '../../datasets/regression/X_validation.csv'
x_val = pd.read_csv(dataset_path5)
dataset_path6 = '../../datasets/regression/y_val.csv'
y_val = pd.read_csv(dataset_path6)

# %% [markdown]
# ## 2. Decision Tree Regressor

# %% [markdown]
# ### 2.1 Model Definition and Training

# %%
decision_tree_regressor = tr.DecisionTreeRegressor(max_depth=42)
decision_tree_regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=42)

# %% [markdown]
# ### 2.2 Model Predict and Performance

# %%
# Predict Train
y_pred_train = decision_tree_regressor.predict(x_train)  

# Performance Metrics
r2_train = mt.r2_score(y_train, y_pred_train)
mse_train = mt.mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mae_train = mt.mean_absolute_error(y_train, y_pred_train)
mape_train = mt.mean_absolute_percentage_error(y_train, y_pred_train)

print(f"Train R2 Square: {r2_train}")
print(f"Train MSE: {mse_train}")
print(f"Train RMSE: {rmse_train}")
print(f"Train MAE: {mae_train}")
print(f"Train MAPE: {mape_train}%")
# Out:
# Train R2 Square: 0.9917566957405923
# Train MSE: 3.940402971731975
# Train RMSE: 1.9850448286454327
# Train MAE: 0.21409852496986279
# Train MAPE: 0.08262787375974134%

# %%
# Predict Validation
y_pred_val = decision_tree_regressor.predict(x_val)  

# Performance Metrics
r2_val = mt.r2_score(y_val, y_pred_val)
mse_val = mt.mean_squared_error(y_val, y_pred_val)
rmse_val = np.sqrt(mse_val)
mae_val = mt.mean_absolute_error(y_val, y_pred_val)
mape_val = mt.mean_absolute_percentage_error(y_val, y_pred_val)

print(f"Validation R2 Square: {r2_val}")
print(f"Validation MSE: {mse_val}")
print(f"Validation RMSE: {rmse_val}")
print(f"Validation MAE: {mae_val}")
print(f"Validation MAPE: {mape_val}%")
# Out:
# Validation R2 Square: -0.27927881682840017
# Validation MSE: 610.8704899655474
# Validation RMSE: 24.71579434219235
# Validation MAE: 17.06031366848885
# Validation MAPE: 7.264373350336664%

# %% [markdown]
# ### 2.3 Fine-tuning

# %%
# Find Best max_depth Hyperparameter for Validation Data
m = np.arange(2, 60, 1)
mse_list = []

for i in m:
    decision_tree_regressor = tr.DecisionTreeRegressor(max_depth=i)
    decision_tree_regressor.fit(x_train, y_train)
    y_pred_val = decision_tree_regressor.predict(x_val) 

    mse = mt.mean_squared_error(y_val, y_pred_val)
    mse_list.append(mse)

plt.plot(m, mse_list, '-o')
plt.xlabel('max_depth value')
plt.ylabel('Mean Squared Error')
plt.show();

# %%
best_m = mse_list.index(min(mse_list))
m[best_m]
# Out:
# 5

# %%
# Predict Validation with Best max_depth Value Found
decision_tree_regressor = tr.DecisionTreeRegressor(max_depth=5)
decision_tree_regressor.fit(x_train, y_train)
y_pred_val = decision_tree_regressor.predict(x_val)  

# Performance Metrics
r2_val = mt.r2_score(y_val, y_pred_val)
mse_val = mt.mean_squared_error(y_val, y_pred_val)
rmse_val = np.sqrt(mse_val)
mae_val = mt.mean_absolute_error(y_val, y_pred_val)
mape_val = mt.mean_absolute_percentage_error(y_val, y_pred_val)

print(f"Validation R2 Square: {r2_val}")
print(f"Validation MSE: {mse_val}")
print(f"Validation RMSE: {rmse_val}")
print(f"Validation MAE: {mae_val}")
print(f"Validation MAPE: {mape_val}%")
# Out:
# Validation R2 Square: 0.06355927779643333
# Validation MSE: 447.16131876114446
# Validation RMSE: 21.146189225511637
# Validation MAE: 16.843451865846713
# Validation MAPE: 8.395778483246199%

# %%
# Predict Test with Best max_depth Value Found
decision_tree_regressor = tr.DecisionTreeRegressor(max_depth=5)
decision_tree_regressor.fit(x_train, y_train)
y_pred_test = decision_tree_regressor.predict(x_test)  

# Performance Metrics
r2_test = mt.r2_score(y_test, y_pred_test)
mse_test = mt.mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mae_test = mt.mean_absolute_error(y_test, y_pred_test)
mape_test = mt.mean_absolute_percentage_error(y_test, y_pred_test)

print(f"Test R2 Square: {r2_test}")
print(f"Test MSE: {mse_test}")
print(f"Test RMSE: {rmse_test}")
print(f"Test MAE: {mae_test}")
print(f"Test MAPE: {mape_test}%")
# Out:
# Test R2 Square: 0.07218138462475543
# Test MSE: 451.7557892724257
# Test RMSE: 21.254547496298898
# Test MAE: 17.010756733330503
# Test MAPE: 7.833952251913887%
